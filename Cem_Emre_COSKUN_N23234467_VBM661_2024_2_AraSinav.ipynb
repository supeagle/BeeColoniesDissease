# %% [markdown]
# <a href="https://colab.research.google.com/github/supeagle/BeeColoniesDissease/blob/main/Cem_Emre_COSKUN_N23234467_VBM661_2024_2_AraSinav.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **VBM661 Veri Görşelleştirme
# Final Sınavı Raporu
# Bee Colonies Veri Setinin Analizi
# Cem Emre COŞKUN
# N23234467**
#
#
#
# ---
#
# **Giriş**
#
# ---
#
# Bee Colonies veri seti Amerika Birleşik Devletlerinde 2015 ile 2021 yılları arasında arı kolonilerini üzerinde yapılan incelemeleri içermekterdir.Bu çalışma kapsamında yıl ve eyalet bazında kolonilerin sayısal değişimleri ve bu değişime etki eden faktörler (parazit,tarım ilaçları v.b) incelenmiştir. Yapılmış olan çalışmalarda yıl 4 periyota bölünmüş olup görselleştirme çalışmalarında yaz ve kış olarak alınmıştır.
#
# **Veri Seti**
#
#
# ---
#
# Bu çalışmada colony.csv ve stressor.csv  olmak üzere iki adet dosya kullanılmıştır. Dosyalar Amerika Birleşik Devletleri için  eyalet, yıl ve sezon bazında kolonilere  ait sayısal verileri, stres türlerini ve verdikleri hasar yüzdelerini  içermektedir.İlgili dosyalara ait detaylı bilgi aşağıda mevcuttur.

# %% [markdown]
# **colony.csv
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **stressor.csv**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Soru 1: 2015 ve 2021 Yılları Arasında Arı Kolonilerinde Sayısal Davranışlar Nasıldır?**
# ![lost.png](data:image/png;base64,...)
#
#
#
# ![reno.png](data:image/png;base64,...)

# %% [markdown]
# **Bulgular:** Yapılan görselleştirmelere sırasıyla bakıldığında yıllık toplam kayıp değerleri 2015 yılıyla 2021 arasında dalgalı olmakla birlikte bir düşüş göstermiştir.En azyıllık toplam kayıp 2021 yılında görülmüştür.Sezonlara bakıldığında yıllık toplamdaki düşüşe benzer bir davranış sergilemekle birlikte kış sezonunda kayıp yaz sezonuna göre çalışma yıllarının tümünde daha yüksektir.
#
# Arı kolonisi eklenme ve renovasyon  grafiklerine  baktığımızda genel olarak yaz sezonlarının kıştan daha yüksek olduğunu söylebiliriz bu duruma sadece 2019 yılının kış sezonu eklenmelerini gösterbilirken renovasyon grafiğinde 2019 yılında sezonları değerleri birbirine çok yakındır.
#
#
# **Kayıp Grafiği İçin:**
#
# Veri işareti: Bar
#
# Kullanılan görsel kanallar:
#
# X-pozisyon: Yıl
#
# Y-pozisyon: Koloni kayıp (milyon)
#
# Renk: sezon
#
#
#
# **Eklenme ve Renovasyon Grafiği İçin:**
#
#
# Veri işareti: Bar
#
# Kullanılan görsel kanallar:
#
# X-pozisyon: Yıl
#
# Y-pozisyon: Koloni kayıp (milyon)
#
# Renk: sezon
#
#
# **Takip Eden Konu:** Çalışmanın sezonluk ve yıllık bazda incelenmesinin yanında eyalet bazında harita üzerinde çalışma yapılan yıllar boyunca arı kolonilerinin ortalama kaybını incelemek daha aydınlatıcı olacaktır.

# %% [markdown]
# **Soru 2: 2015 ile 2021 Yılları Yapılan İnceleme Boyunca Eyaletlere Göre Arı Kolonilerinin Ortalama Kayıp Yüzdelerindeki Dağılım Nedir?**
#
# ![eyalet.png](data:image/png;base64,...)

# %% [markdown]
# **Bulgular:** 2015 ile 2021 yıllarında yapılan çalışma boyunca eyaletlere göre arı kolonilerinin ortalama kayıp yüzdelerine bakıldığında yüksek oranda kayıp olan eyaletler sırasıyla Kansas (KS), Arizona (AZ) ve New Mexio (NM) olduğu açıkça görülmektedir. Ülkenin kuzey batı eyaletlerinde ortalama kayıp oranı görece düşük gözlenmekte olup doğru eyaletlerinde grafikteki yüksek  kayıp rengine ait yoğunluk (>12.5%) görülmektedir.Alaska (AK), Nevada (NV),New Hampshire (NH) eyaletlerinde kayıp gözlemlenmemiştir.
# Veri işareti: Harita
#
# Kullanılan görsel kanallar:
#
# X-pozisyon: Boylam -Meridyen
#
# Y-pozisyon: Enlem - Paralel
#
# (Alaska ve Hawaii eyaletleri Fundamentals of Data Visualization'daki görselleştirme örneği gereği haritadaki yerleri revize edilmiştir.)
#
# Renk: Ortalama Arı Kolonisi Kayıp Yüzdesi
#
# **Takip Eden Konu:** Harita üzerindeki çalışma boyuncaki ortalama kayıp yüzdelerini inceledikten sonra bu kayıpların sebeplerini oluşturan stres faktörlerini ve yıllık kayba hangi oranda etki gösterdiklerini incelemek aydınlatıcı olaracaktır.

# %% [markdown]
# **Soru3:Arı kolonileri kayıplarında etkili olan stres faktörlerinin eyalet ve yıl bazında davranışları nelerdir?**
#
# ![animasyon.png](data:image/png;base64,...)

# %% [markdown]
# **Bulgular:** Stres türlerinin eyaletlerde yıllık kayıplara etki ortalamaları incelendiği bu animasyonlu görselleştirmede çalışma boyunca (2015-2021) varroa mite başta olmak üzere,parazitler, pesticides(tarım ilaçları),salgınlar ve diğer sebeplerin(other) etkilerini görmekteyiz.Bu stres türlerin değer ve sıralamarı yıl ve eyalet bazında  değişiklik göstermekle birlikte varroa mite,parazit ve pesticides(tarım ilaçları) kategorileri çoğunlukla bu sıralamayla  eyaletlerin yıllık arı kolonisi kayıplarına sebep olmaktadır.
#
#
# **İlgili animasyon raporun sonunda yer almaktadır.
#
# Veri işareti: Scatter/Dağılım
#
# Kullanılan görsel kanallar:
#
# X-pozisyon: Yıllık Ortalama Stres Yüzdesi
#
# Y-pozisyon: Eyaletler
#
# Animasyon Çercevesi : Yıl
#
# Şekil ve Renk : Stres Türü

# %% [markdown]
# **Kaynakça**
#
# R for Data Science Community. (2023). TidyTuesday Data for the week of January 5, 2022. GitHub Retvieved May 16,2024 from;
#
# https://github.com/rfordatascience/tidytuesday/blob/master/data/2022/2022-01-11/readme.md
#
#
# The USDA Economics
#
# https://usda.library.cornell.edu/concern/publications/rn301137d?locale=en

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import geopandas as gpd
import plotly.graph_objs as go
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-01-11/colony.csv"
data = pd.read_csv(url)
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222 entries, 0 to 1221
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             1222 non-null   int64
#  1   months           1222 non-null   object
#  2   state            1222 non-null   object
#  3   colony_n         1175 non-null   float64
#  4   colony_max       1150 non-null   float64
#  5   colony_lost      1175 non-null   float64
#  6   colony_lost_pct  1168 non-null   float64
#  7   colony_added     1139 non-null   float64
#  8   colony_reno      1091 non-null   float64
#  9   colony_reno_pct  962 non-null    float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 95.6+ KB

# %%
del data['colony_n']

# %%
data = data.rename(columns={'colony_max': 'colony_number'})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222 entries, 0 to 1221
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             1222 non-null   int64
#  1   months           1222 non-null   object
#  2   state            1222 non-null   object
#  3   colony_number    1150 non-null   float64
#  4   colony_lost      1175 non-null   float64
#  5   colony_lost_pct  1168 non-null   float64
#  6   colony_added     1139 non-null   float64
#  7   colony_reno      1091 non-null   float64
#  8   colony_reno_pct  962 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 86.0+ KB

# %%
data.tail(10)
# Out:
#       year      months          state  colony_number  colony_lost  \
# 1212  2021  April-June          Texas       425000.0      34000.0
# 1213  2021  April-June           Utah        31000.0       3500.0
# 1214  2021  April-June        Vermont         7000.0         40.0
# 1215  2021  April-June       Virginia         8500.0        530.0
# 1216  2021  April-June     Washington       122000.0       2900.0
# 1217  2021  April-June  West Virginia         9000.0        170.0
# 1218  2021  April-June      Wisconsin        57000.0       2200.0
# 1219  2021  April-June        Wyoming        30000.0       3400.0
# 1220  2021  April-June   Other States         8410.0        140.0
# 1221  2021  April-June  United States            NaN     255860.0
#
#       colony_lost_pct  colony_added  colony_reno  colony_reno_pct
# 1212              8.0       65000.0      72000.0             17.0
# 1213             11.0        8500.0       3900.0             13.0
# ...

# %%
# Yaz ve kış dönemlerini tanımlama
def season(months):
    if months in ['April-June', 'July-September']:
        return 'Yaz'
    else:
        return 'Kış'

data['season'] = data['months'].apply(season)

print(data.tail())
print(data.head())
# Out:
#       year      months          state  colony_number  colony_lost  \
# 1217  2021  April-June  West Virginia         9000.0        170.0
# 1218  2021  April-June      Wisconsin        57000.0       2200.0
# 1219  2021  April-June        Wyoming        30000.0       3400.0
# 1220  2021  April-June   Other States         8410.0        140.0
# 1221  2021  April-June  United States            NaN     255860.0
#
#       colony_lost_pct  colony_added  colony_reno  colony_reno_pct season
# 1217              2.0        1900.0        390.0              4.0    Yaz
# 1218              4.0        9000.0       7500.0             13.0    Yaz
# 1219             11.0        7500.0       4900.0             16.0    Yaz
# 1220              2.0        2890.0       3100.0             37.0    Yaz
# 1221              9.0      677690.0     480380.0             17.0    Yaz
#    year         months       state  colony_number  colony_lost  \
# 0  2015  January-March     Alabama         7000.0       1800.0
# ...

# %%
seasonal_loss = data.groupby(['year', 'season'])['colony_lost'].sum().reset_index()

# Toplam kayıpları hesaplamak için yaz ve kış kayıplarını birleştirme
total_loss = seasonal_loss.groupby('year')['colony_lost'].sum().reset_index()
total_loss['season'] = 'Toplam'
seasonal_loss = pd.concat([seasonal_loss, total_loss], ignore_index=True)

# Zamansal çizgi grafiği oluşturma
plt.figure(figsize=(12, 8))
sns.barplot(data=seasonal_loss, x='year', y='colony_lost', hue='season', palette="plasma")
plt.title('Yaz, Kış ve Yıllık Toplam Arı Kolonisi Kayıpları')
plt.xlabel('Yıl')
plt.ylabel('Koloni Kayıpları (milyon)')
plt.grid(True)
plt.show()

# %%
# Yıllık toplam eklemeler ve renovasyonlar
annual_add_reno = data.groupby(['year', 'season'])[['colony_added', 'colony_reno']].sum().reset_index()

# Veri çerçevesinin ilk birkaç satırını görüntüleyin
print(annual_add_reno.head())
print(annual_add_reno.tail())
# Out:
#    year season  colony_added  colony_reno
# 0  2015    Kış     1328260.0     858640.0
# 1  2015    Yaz     1669700.0    1991840.0
# 2  2016    Kış     1005640.0     436880.0
# 3  2016    Yaz     1908480.0    1686580.0
# 4  2017    Kış     1581500.0     907140.0
#     year season  colony_added  colony_reno
# 9   2019    Yaz      505100.0     710660.0
# 10  2020    Kış     1497400.0     564760.0
# 11  2020    Yaz     1890280.0    2028600.0
# 12  2021    Kış      617060.0     312540.0
# 13  2021    Yaz     1355380.0     960760.0

# %%
plt.figure(figsize=(12, 8))

# Colony Added bar grafiği
plt.subplot(2, 1, 1)
sns.barplot(data=annual_add_reno, x='year', y='colony_added', hue='season')
plt.title('Yıllık Toplam Arı Kolonisi Eklenmeleri (Yaz ve Kış)')
plt.xlabel('Yıl')
plt.ylabel('Toplam Arı Kolonisi Eklemeleri (milyon)')

# Colony Renovated bar grafiği
plt.subplot(2, 1, 2)
sns.barplot(data=annual_add_reno, x='year', y='colony_reno', hue='season')
plt.title('Yıllık Toplam Arı Kolonisi Renovasyonları (Yaz ve Kış)')
plt.xlabel('Yıl')
plt.ylabel('Toplam Arı Kolonisi Renovasyonları (milyon)')

plt.tight_layout()
plt.show()

# %%
print(data['state'].unique())
# Out:
# ['Alabama' 'Arizona' 'Arkansas' 'California' 'Colorado' 'Connecticut'
#  'Florida' 'Georgia' 'Hawaii' 'Idaho' 'Illinois' 'Indiana' 'Iowa' 'Kansas'
#  'Kentucky' 'Louisiana' 'Maine' 'Maryland' 'Massachusetts' 'Michigan'
#  'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'Nebraska' 'New Jersey'
#  'New Mexico' 'New York' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma'
#  'Oregon' 'Pennsylvania' 'South Carolina' 'South Dakota' 'Tennessee'
#  'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington' 'West Virginia'
#  'Wisconsin' 'Wyoming' 'Other States' 'United States']

# %%
data = data[~data['state'].isin(['United States', 'Other States', 'AK'])]

data['colony_lost_pct'] = data['colony_lost_pct'].fillna(0)
# Out:
# <ipython-input-12-baa76f845c17>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['colony_lost_pct'] = data['colony_lost_pct'].fillna(0)

# %%
state_avg_loss_pct = data.groupby('state')['colony_lost_pct'].mean().sort_values()

all_states = {
    'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'Florida',
    'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine',
    'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
    'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio',
    'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas',
    'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'
}
missing_states = all_states - set(state_avg_loss_pct.index)
for state in missing_states:
    state_avg_loss_pct[state] = 0

url = 'https://raw.githubusercontent.com/PublicaMundi/MappingAPI/master/data/geojson/us-states.json'
states = gpd.read_file(url)

# Eyalet ikili kodları
state_abbreviations = {
    'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 'Colorado': 'CO',
    'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA', 'Hawaii': 'HI', 'Idaho': 'ID',
    'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA',
    'Maine': 'ME', 'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS',
    'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 'New Jersey': 'NJ',
    'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK',
    'Oregon': 'OR', 'Pennsylvania': 'PA', 'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD',
    'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA',
    'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY'
}
states['abbr'] = states['name'].map(state_abbreviations)

state_avg_loss_pct_df = state_avg_loss_pct.reset_index()
state_avg_loss_pct_df.columns = ['state', 'avg_colony_lost_pct']
merged = states.merge(state_avg_loss_pct_df, left_on='name', right_on='state')

merged = merged.to_crs(epsg=2163)

alaska = merged[merged['abbr'] == 'AK']
hawaii = merged[merged['abbr'] == 'HI']

alaska = alaska.copy()
hawaii = hawaii.copy()
alaska['geometry'] = alaska.translate(xoff=-600000, yoff=-5000000).geometry
hawaii['geometry'] = hawaii.translate(xoff=5700000, yoff=-2000000).geometry

merged = merged[(merged['abbr'] != 'AK') & (merged['abbr'] != 'HI')]

fig, ax = plt.subplots(1, 1, figsize=(15, 10))
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

fig.patch.set_facecolor('lightgrey')
ax.set_facecolor('lightgrey')

merged.plot(column='avg_colony_lost_pct', ax=ax, legend=True, cax=cax,
            legend_kwds={'label': "Ortalama Arı Kolonisi Kayıp Yüzdesi",
                         'orientation': "vertical"},
            cmap='OrRd', vmin=0, vmax=20)

alaska.plot(column='avg_colony_lost_pct', ax=ax, legend=False, cmap='OrRd', vmin=0, vmax=18)
hawaii.plot(column='avg_colony_lost_pct', ax=ax, legend=False, cmap='OrRd', vmin=0, vmax=18)

for x, y, label in zip(merged.geometry.centroid.x, merged.geometry.centroid.y, merged['abbr']):
    ax.text(x, y, label, fontsize=8, ha='center')
for x, y, label in zip(alaska.geometry.centroid.x, alaska.geometry.centroid.y, alaska['abbr']):
    ax.text(x, y, label, fontsize=8, ha='center')
for x, y, label in zip(hawaii.geometry.centroid.x, hawaii.geometry.centroid.y, hawaii['abbr']):
    ax.text(x, y, label, fontsize=8, ha='center')

plt.suptitle('2015 ile 2021 Yıllarında Çalışma Boyunca Eyaletlere Göre Ortalama Arı Kolonisi Kayıp Yüzdeleri', y=0.95)

ax.axis('off')
plt.show()

# %%
alaska['geometry'] = alaska.translate(xoff=-600000, yoff=-5000000).geometry
hawaii['geometry'] = hawaii.translate(xoff=5700000, yoff=-2000000).geometry

# %%
state_avg_loss_pct
# Out:
# state
# Hawaii             5.038462
# New Jersey         5.076923
# Vermont            5.115385
# Montana            5.730769
# North Dakota       6.769231
# Connecticut        6.923077
# Oregon             7.192308
# Louisiana          7.230769
# South Dakota       7.692308
# Maine              8.192308
# Nebraska           8.384615
# Texas              8.615385
# Washington         8.653846
# Wyoming            9.346154
# Mississippi        9.769231
# Oklahoma           9.807692
# Idaho              9.846154
# Missouri           9.923077
# Minnesota         10.038462
# South Carolina    10.346154
# Iowa              10.692308
# California        10.730769
# New York          10.769231
# Utah              11.038462
# Michigan          11.115385
# Maryland          11.615385
# Massachusetts     11.730769
# West Virginia     11.730769
# Pennsylvania      11.807692
# North Carolina    12.115385
# Indiana           12.384615
# Wisconsin         12.461538
# Virginia          12.692308
# ...

# %%
state_avg_loss_pct.max()
# Out:
# 18.576923076923077

# %%
url_2="https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-01-11/stressor.csv"
data_2=pd.read_csv(url_2)
data_2.head()
# Out:
#    year         months    state               stressor  stress_pct
# 0  2015  January-March  Alabama           Varroa mites        10.0
# 1  2015  January-March  Alabama  Other pests/parasites         5.4
# 2  2015  January-March  Alabama              Disesases         NaN
# 3  2015  January-March  Alabama             Pesticides         2.2
# 4  2015  January-March  Alabama                  Other         9.1

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7332 entries, 0 to 7331
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        7332 non-null   int64
#  1   months      7332 non-null   object
#  2   state       7332 non-null   object
#  3   stressor    7332 non-null   object
#  4   stress_pct  6489 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 286.5+ KB

# %%
data_2['stress_pct'] = data_2['stress_pct'].fillna(0)
data_2 = data_2[~data_2['state'].isin(['United States', 'Other States'])]


annual_stress = data_2.groupby(['year','state','stressor'])['stress_pct'].mean().reset_index()
print(annual_stress.head(10))
# Out:
#    year    state               stressor  stress_pct
# 0  2015  Alabama              Disesases       0.050
# 1  2015  Alabama                  Other       4.325
# 2  2015  Alabama  Other pests/parasites      31.225
# 3  2015  Alabama             Pesticides       1.825
# 4  2015  Alabama                Unknown       8.275
# 5  2015  Alabama           Varroa mites      23.225
# 6  2015  Arizona              Disesases       1.775
# 7  2015  Arizona                  Other       9.525
# 8  2015  Arizona  Other pests/parasites      19.775
# 9  2015  Arizona             Pesticides      10.225

# %%
fig = px.scatter(
    data_frame=annual_stress,
    x='stress_pct',
    y='state',
    size='stress_pct',
    color='stressor',
    symbol='stressor',
    range_x=[0, max(annual_stress['stress_pct']) + 5],
    labels={'stress_pct': 'Stres Yüzdesi (%)', 'stressor': 'Stres Türü', 'year': 'Yıl', 'state': 'Eyalet'},
    title='Stres Türlerinin Yıllık Verdiği Hasar Yüzdesi Ortalamaları',
    hover_name='stressor',
    animation_frame='year',
    height=800,
    size_max=50,
    color_discrete_sequence=px.colors.qualitative.Plotly
)

fig.update_layout(
    showlegend=True,
    xaxis_title='Stres Yüzdesi Ortalaması (%)',
    yaxis_title='Eyalet',
    template='plotly_dark'
)


fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 3000
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 2000

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
